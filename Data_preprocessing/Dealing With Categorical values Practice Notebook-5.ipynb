# %% [markdown]
# # Dealing With Categorical Values

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing Dataset

# %%
dataset = pd.read_csv("Salary_Dataset.csv")

# %%
dataset.head()
# Out:
#   country   Salary  YearsExperience Purchased
# 0   Dubai  39343.0              1.1        No
# 1  Canada  46205.0              1.3       Yes
# 2  Canada  37731.0              1.5        No
# 3  Canada  43525.0              2.0        No
# 4     USA  39891.0              2.2        No

# %% [markdown]
# # Lets perform Encoding

# %% [markdown]
# ## Applying One-Hot Encoding

# %% [markdown]
# <h3> First Do it with pandas </h3>

# %% [markdown]
# Categorical value converts into some label/numerical values using some methods-
# 1. One-Hot Encoding, Alphabetically sorting
# 2. Label Encoding

# %% [markdown]
# For country:- One-hot Encoding
#
# For Purchased:- Label Encoding

# %%
# country_dummy = pd.get_dummies(dataset['country'], dtype=int)
# country_dummy.head()
country_dummy = pd.get_dummies(dataset['country']).astype(int)
country_dummy.head()
# Out:
#    Australia  Canada  Dubai  USA
# 0          0       0      1    0
# 1          0       1      0    0
# 2          0       1      0    0
# 3          0       1      0    0
# 4          0       0      0    1

# %%
# concatenate the dataframes into original dataframes.
dataset = pd.concat([dataset, country_dummy], axis=1)
dataset.head(10)
# Out:
#      country   Salary  YearsExperience Purchased  Australia  Canada  Dubai  \
# 0      Dubai  39343.0              1.1        No          0       0      1
# 1     Canada  46205.0              1.3       Yes          0       1      0
# 2     Canada  37731.0              1.5        No          0       1      0
# 3     Canada  43525.0              2.0        No          0       1      0
# 4        USA  39891.0              2.2        No          0       0      0
# 5      Dubai  56642.0              2.9        No          0       0      1
# 6     Canada  60150.0              3.0       Yes          0       1      0
# 7  Australia  54445.0              3.2        No          1       0      0
# 8      Dubai  64445.0              3.2       Yes          0       0      1
# 9      Dubai  57189.0              3.7        No          0       0      1
#
#    USA
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# 5    0
# 6    0
# 7    0
# 8    0
# 9    0

# %%
# Drop the country column and rearrange the index of column.
dataset.drop('country', axis=1, inplace=True)
dataset.head()
# Out:
#     Salary  YearsExperience Purchased  Australia  Canada  Dubai  USA
# 0  39343.0              1.1        No          0       0      1    0
# 1  46205.0              1.3       Yes          0       1      0    0
# 2  37731.0              1.5        No          0       1      0    0
# 3  43525.0              2.0        No          0       1      0    0
# 4  39891.0              2.2        No          0       0      0    1

# %%
dataset= dataset[['Australia', 'Canada', 'Dubai', 'USA', 'YearsExperience', 'Salary', 'Purchased']]
dataset.head()
# Out:
#    Australia  Canada  Dubai  USA  YearsExperience   Salary Purchased
# 0          0       0      1    0              1.1  39343.0        No
# 1          0       1      0    0              1.3  46205.0       Yes
# 2          0       1      0    0              1.5  37731.0        No
# 3          0       1      0    0              2.0  43525.0        No
# 4          0       0      0    1              2.2  39891.0        No

# %%
# dataset_1.to_csv('New_salary', index=False)

# %% [markdown]
# # <h3> Let's do it with Scikit-Learn </h3>
# Also Restart your kernel if you are using same notebook

# %%
dataset = pd.read_csv("Salary_Dataset.csv")

# %%
dataset.head(5)
# Out:
#   country   Salary  YearsExperience Purchased
# 0   Dubai  39343.0              1.1        No
# 1  Canada  46205.0              1.3       Yes
# 2  Canada  37731.0              1.5        No
# 3  Canada  43525.0              2.0        No
# 4     USA  39891.0              2.2        No

# %%
# Lets first perform label encoding
# Label encoding will be performed on Purchased column as it has only two unique value in it.
from sklearn.preprocessing import LabelEncoder
# have to make an instance 
le = LabelEncoder()
dataset['Purchased'] = le.fit_transform(dataset['Purchased'])
dataset.head()
# Out:
#   country   Salary  YearsExperience  Purchased
# 0   Dubai  39343.0              1.1          0
# 1  Canada  46205.0              1.3          1
# 2  Canada  37731.0              1.5          0
# 3  Canada  43525.0              2.0          0
# 4     USA  39891.0              2.2          0

# %%
# Lets perform one-hot encoding on country column.
# one-hot encoding with ColumnTransformer 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
dataset = pd.DataFrame(ct.fit_transform(dataset))
dataset.columns = ['Australia',	'Canada', 'Dubai', 'USA', 'Salary', 'YearsExperience','Purchased']
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 8
#       6 ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
#       7 dataset = pd.DataFrame(ct.fit_transform(dataset))
# ----> 8 dataset.columns = ['Australia',	'Canada', 'Dubai',	'USA', 'Salary', 'YearsExperience','Purchased']
#       9 dataset.head()
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6335, in NDFrame.__setattr__(self, name, value)
#    6333 try:
#    6334     object.__getattribute__(self, name)
# -> 6335     return object.__setattr__(self, name, value)
#    6336 except AttributeError:
#    6337     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:817, in NDFrame._set_axis(self, axis, labels)
#     812 """
#     813 This is called from the cython code when we set the `index` attribute
#     814 directly, e.g. `series.index = [1, 2, 3]`.
#     815 """
#     816 labels = ensure_index(labels)
# --> 817 self._mgr.set_axis(axis, labels)
#     818 self._clear_item_cache()
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 10 elements, new values have 7 elements

# %%
#Lets link the headers name.
